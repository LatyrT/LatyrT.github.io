# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


#-------------------------------
# Added By Latyr

import requests
import json
from pprint import pprint
from config import weather_api_key
from config import g_key
import time
#-------------------------------


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 594

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities
Latitude = []
Longitude = []
Temperature = []
Selected_City = []
Humidity = []
Cloudiness = []
Wind_Speed = []
Max_Temp = []
City_ID = []
Country = []


Record_Number = 0
Set_Number = 1


print(f"Beginning Data Retrieval")
print(f"------------------------------------")


for city in cities:
    # Save config information
    url = "http://api.openweathermap.org/data/2.5/weather?"
    #query_url = url + "&q=" + city + "&appid=" + weather_api_key
    Query_url = url + "&q=" + city + "&appid=" + weather_api_key
    #print(Query_url)
    
    Responses = requests.get(Query_url)
    Reponses_Json = Responses.json()
    #Weather_Data.append(Reponses_Json)
    Weather_Data = Reponses_Json
    

    if  Record_Number < 50:
        Record_Number = Record_Number + 1
        Set_Number = Set_Number 
        
    else:   
        Record_Number = 0
        Set_Number = Set_Number + 1
    
    print("+++++++++++++++++++++++++++++++++")
    print(f"Processing Record {Record_Number} of Set {Set_Number} | {city}")
       
 
    #pprint(Weather_Data)
    time.sleep(1.05)

    
    try:
        Selected_City.append(Weather_Data["name"])
        Latitude.append(Weather_Data["coord"]["lat"])
        Longitude.append(Weather_Data["coord"]["lon"])
        Temperature.append(Weather_Data["main"]["temp"])
        Humidity.append(Weather_Data["main"]["humidity"])
        Max_Temp.append(Weather_Data["main"]["temp_max"])
        Wind_Speed.append(Weather_Data["wind"]["speed"])
        Cloudiness.append(Weather_Data["clouds"]["all"])
        City_ID.append(Weather_Data["id"])
        Country.append(Weather_Data["sys"]["country"])
        print(f"City ID: " + str(Weather_Data["id"]))
        print("+++++++++++++++++++++++++++++++++")

        

    except Exception as exc:
        # Append null values
        print("City not found. Skipping...")
        print(exc)
        pass


print("###################################")
print(f"Completed!!!!!")
print("###################################")
# Out:
# Beginning Data Retrieval
# ------------------------------------
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 1 | methoni
# City ID: 257122
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 1 | puerto ayora
# City ID: 3652764
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 1 | vaini
# City ID: 4032243
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 1 | ponta do sol
# City ID: 2264557
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 1 | ushuaia
# City ID: 3833367
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 1 | bluff
# City ID: 2206939
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 1 | san quintin
# City ID: 3984997
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 1 | punta arenas
# City ID: 3874787
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 1 | kaitangata
# City ID: 2208248
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 1 | mattawa
# City ID: 5802636
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 1 | albany
# City ID: 5106841
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 1 | dingle
# City ID: 1714733
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 1 | aksarayskiy
# City ID: 583683
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 1 | rikitea
# City ID: 4030556
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 1 | mahebourg
# City ID: 934322
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 1 | arouca
# City ID: 3575039
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 1 | aden
# City ID: 415189
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 1 | vardo
# City ID: 777019
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 1 | achit
# City ID: 584308
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 1 | xuchang
# City ID: 1788046
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 1 | ihosy
# City ID: 1064275
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 1 | cairns
# City ID: 2172797
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 1 | fortuna
# City ID: 5563839
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 1 | amderma
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 1 | chuy
# City ID: 3443061
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 1 | sitka
# City ID: 5557293
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 1 | dikson
# City ID: 1507390
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 1 | busselton
# City ID: 2075265
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 1 | saldanha
# City ID: 3361934
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 1 | tahta
# City ID: 347634
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 1 | chernyshevskiy
# City ID: 2025456
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 34 of Set 1 | hermanus
# City ID: 3366880
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 35 of Set 1 | botou
# City ID: 1816256
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 36 of Set 1 | qaanaaq
# City ID: 3831208
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 37 of Set 1 | yar-sale
# City ID: 1486321
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 38 of Set 1 | sisauli
# City ID: 1256003
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 39 of Set 1 | tiksi
# City ID: 2015306
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 40 of Set 1 | tuatapere
# City ID: 2180815
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 41 of Set 1 | sao filipe
# City ID: 3374210
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 42 of Set 1 | bafra
# City ID: 751335
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 43 of Set 1 | abalak
# City ID: 1512223
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 44 of Set 1 | kenora
# City ID: 5991056
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 45 of Set 1 | bredasdorp
# City ID: 1015776
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 46 of Set 1 | ponta delgada
# City ID: 3372783
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 48 of Set 1 | saint-philippe
# City ID: 935215
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 49 of Set 1 | kloulklubed
# City ID: 7671223
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 50 of Set 1 | atuona
# City ID: 4020109
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 0 of Set 2 | coihaique
# City ID: 3894426
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 2 | alta floresta
# City ID: 6316343
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 2 | ilorin
# City ID: 2337639
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 2 | chokurdakh
# City ID: 2126123
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 2 | wukari
# City ID: 2318921
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 2 | bambous virieux
# City ID: 1106677
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 2 | kegayli
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 2 | pisco
# City ID: 3932145
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 2 | maues
# City ID: 3395062
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 2 | saskylakh
# City ID: 2017155
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 2 | saint-ambroise
# City ID: 6137381
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 2 | nikolskoye
# City ID: 546105
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 2 | lagoa
# City ID: 3372964
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 2 | gat
# City ID: 293842
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 2 | alotau
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 2 | narsaq
# City ID: 3421719
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 2 | mataura
# City ID: 6201424
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 2 | oum hadjer
# City ID: 2426370
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 2 | nago
# City ID: 1856068
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 2 | opotiki
# City ID: 2208332
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 2 | ngukurr
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 2 | jamestown
# City ID: 5122534
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 2 | azimur
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 2 | pozo colorado
# City ID: 3437443
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 2 | jalu
# City ID: 86049
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 2 | cape town
# City ID: 3369157
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 2 | sabang
# City ID: 1214026
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 2 | kiama
# City ID: 2161515
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 2 | longyearbyen
# City ID: 2729907
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 2 | thonon-les-bains
# City ID: 2972741
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 2 | cap malheureux
# City ID: 934649
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 2 | kapaa
# City ID: 5848280
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 2 | pevek
# City ID: 2122090
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 34 of Set 2 | hobart
# City ID: 2163355
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 35 of Set 2 | faanui
# City ID: 4034551
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 36 of Set 2 | saint george
# City ID: 5546220
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 37 of Set 2 | isangel
# City ID: 2136825
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 38 of Set 2 | touros
# City ID: 3386213
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 39 of Set 2 | noumea
# City ID: 2139521
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 40 of Set 2 | talnakh
# City ID: 1490256
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 41 of Set 2 | mar del plata
# City ID: 3430863
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 42 of Set 2 | castro
# City ID: 3466704
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 43 of Set 2 | tautira
# City ID: 4033557
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 44 of Set 2 | east grinstead
# City ID: 2650435
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 45 of Set 2 | haines junction
# City ID: 5969025
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 46 of Set 2 | atar
# City ID: 2381334
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 47 of Set 2 | nanortalik
# City ID: 3421765
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 48 of Set 2 | barrow
# City ID: 5880054
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 49 of Set 2 | bilma
# City ID: 2446796
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 50 of Set 2 | norman wells
# City ID: 6089245
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 0 of Set 3 | mys shmidta
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 3 | butaritari
# City ID: 2110227
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 3 | makakilo city
# City ID: 5850554
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 3 | mamallapuram
# City ID: 1263997
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 3 | husavik
# City ID: 2629833
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 3 | rawson
# City ID: 3839307
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 3 | kozan
# City ID: 306112
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 3 | dunedin
# City ID: 2191562
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 3 | aksarka
# City ID: 1512019
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 3 | carutapera
# City ID: 3402648
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 3 | port alfred
# City ID: 964432
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 3 | pacific grove
# City ID: 5380437
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 3 | karaul
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 3 | victoria
# City ID: 1819729
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 3 | hithadhoo
# City ID: 1282256
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 3 | suzun
# City ID: 1490551
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 3 | toyooka
# City ID: 1849831
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 3 | nichinan
# City ID: 1855476
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 3 | ostrovnoy
# City ID: 556268
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 3 | arraial do cabo
# City ID: 3471451
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 3 | avarua
# City ID: 4035715
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 3 | chepareria
# City ID: 199604
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 3 | sola
# City ID: 2134814
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 3 | cabedelo
# City ID: 3404558
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 3 | severo-kurilsk
# City ID: 2121385
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 3 | merauke
# City ID: 2082539
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 3 | tsumeb
# City ID: 3352593
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 3 | coquimbo
# City ID: 3893629
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 3 | zarautz
# City ID: 3104316
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 3 | port-gentil
# City ID: 2396518
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 3 | clyde river
# City ID: 5924351
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 3 | parry sound
# City ID: 6098747
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 3 | adrar
# City ID: 2381972
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 34 of Set 3 | smithers
# City ID: 6149996
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 35 of Set 3 | gunnedah
# City ID: 2164206
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 36 of Set 3 | hanmer springs
# City ID: 2190299
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 37 of Set 3 | ilulissat
# City ID: 3423146
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 38 of Set 3 | bud
# City ID: 4255151
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 39 of Set 3 | upernavik
# City ID: 3418910
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 41 of Set 3 | torbay
# City ID: 6167817
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 42 of Set 3 | bargal
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 43 of Set 3 | souillac
# City ID: 933995
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 44 of Set 3 | vredendal
# City ID: 3359736
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 45 of Set 3 | acari
# City ID: 3948613
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 46 of Set 3 | bethel
# City ID: 5282297
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 47 of Set 3 | coahuayana
# City ID: 4013679
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 48 of Set 3 | cabo san lucas
# City ID: 3985710
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 49 of Set 3 | hambantota
# City ID: 1244926
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 50 of Set 3 | anadyr
# City ID: 2127202
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 0 of Set 4 | cherskiy
# City ID: 2126199
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 4 | fuente de oro
# City ID: 3682299
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 4 | pueblo nuevo
# City ID: 4007676
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 4 | bogorodskoye
# City ID: 575521
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 4 | fairbanks
# City ID: 5861897
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 4 | laguna
# City ID: 5364271
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 4 | calvinia
# City ID: 3369174
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 4 | yellowknife
# City ID: 6185377
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 4 | tigil
# City ID: 2120612
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 4 | abu samrah
# City ID: 172515
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 4 | khao yoi
# City ID: 1152919
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 4 | kirakira
# City ID: 2178753
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 4 | ushtobe
# City ID: 1517637
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 4 | sisimiut
# City ID: 3419842
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 4 | leczna
# City ID: 766583
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 4 | buraydah
# City ID: 107304
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 4 | ixtapa
# City ID: 4004293
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 4 | katsuura
# City ID: 2112309
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 4 | sao jose da coroa grande
# City ID: 3388456
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 4 | olafsvik
# City ID: 3414079
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 4 | sao miguel do oeste
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 4 | progreso
# City ID: 3521108
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 4 | uni
# City ID: 478996
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 4 | bardiyah
# City ID: 80509
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 4 | ishigaki
# City ID: 1861416
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 4 | mokhsogollokh
# City ID: 2019867
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 4 | verkhnevilyuysk
# City ID: 2013639
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 4 | dubbo
# City ID: 2168305
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 4 | thompson
# City ID: 6165406
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 4 | juneau
# City ID: 5554072
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 4 | saint-pierre
# City ID: 935214
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 4 | pokhara
# City ID: 1282898
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 4 | matara
# City ID: 1235846
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 4 | sentyabrskiy
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 34 of Set 4 | kunming
# City ID: 1804651
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 35 of Set 4 | tonj
# City ID: 365763
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 36 of Set 4 | bella union
# City ID: 3443631
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 37 of Set 4 | vao
# City ID: 2137773
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 38 of Set 4 | igarka
# City ID: 1505991
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 39 of Set 4 | louisbourg
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 40 of Set 4 | pahrump
# City ID: 5509851
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 41 of Set 4 | kodiak
# City ID: 5866583
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 42 of Set 4 | lillehammer
# City ID: 6453350
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 43 of Set 4 | harrison
# City ID: 4429197
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 44 of Set 4 | stupino
# City ID: 486968
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 45 of Set 4 | koumac
# City ID: 2140558
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 46 of Set 4 | flinders
# City ID: 6255012
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 47 of Set 4 | rosetta
# City ID: 350203
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 48 of Set 4 | petropavlovsk-kamchatskiy
# City ID: 2122104
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 49 of Set 4 | plettenberg bay
# City ID: 964712
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 50 of Set 4 | zamora
# City ID: 3649959
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 0 of Set 5 | esperance
# City ID: 2071860
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 5 | new norfolk
# City ID: 2155415
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 5 | nizhneyansk
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 5 | sabha
# City ID: 2212775
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 5 | havelock
# City ID: 4470244
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 5 | ahipara
# City ID: 2194098
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 5 | beruwala
# City ID: 1249931
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 5 | komsomolskiy
# City ID: 1513491
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 5 | tuktoyaktuk
# City ID: 6170031
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 5 | presidencia roque saenz pena
# City ID: 3840300
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 5 | asau
# City ID: 686090
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 5 | verkhnyaya inta
# City ID: 1487332
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 5 | kaeo
# City ID: 2189343
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 5 | yerbogachen
# City ID: 2012956
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 5 | port elizabeth
# City ID: 964420
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 5 | sungairaya
# City ID: 1625908
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 5 | provideniya
# City ID: 4031574
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 5 | koindu
# City ID: 2409751
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 5 | sao gabriel da cachoeira
# City ID: 3662342
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 5 | aranos
# City ID: 3358666
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 5 | lebu
# City ID: 3883457
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 5 | velsk
# City ID: 475938
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 5 | yairipok
# City ID: 1252810
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 5 | hilo
# City ID: 5855927
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 5 | ciudad bolivar
# City ID: 3645532
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 5 | sao geraldo do araguaia
# City ID: 3388760
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 5 | yulara
# City ID: 6355222
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 5 | aklavik
# City ID: 5882953
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 5 | rawannawi
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 5 | marcona
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 5 | ballina
# City ID: 2177069
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 5 | bacolod
# City ID: 1729564
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 5 | richards bay
# City ID: 962367
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 5 | boa vista
# City ID: 3664980
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 34 of Set 5 | puerto escondido
# City ID: 3520994
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 35 of Set 5 | korla
# City ID: 1529376
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 36 of Set 5 | east london
# City ID: 1006984
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 37 of Set 5 | quelimane
# City ID: 1028434
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 38 of Set 5 | sibolga
# City ID: 1213855
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 40 of Set 5 | etchoropo
# City ID: 4006387
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 41 of Set 5 | guerrero negro
# City ID: 4021858
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 42 of Set 5 | muroto
# City ID: 1856392
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 43 of Set 5 | praia
# City ID: 3374333
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 44 of Set 5 | kurilsk
# City ID: 2123979
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 45 of Set 5 | khipro
# City ID: 1173889
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 46 of Set 5 | anahuac
# City ID: 4013726
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 47 of Set 5 | bernal
# City ID: 3699350
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 48 of Set 5 | saleaula
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 49 of Set 5 | picota
# City ID: 3693646
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 50 of Set 5 | awjilah
# City ID: 88533
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 0 of Set 6 | attawapiskat
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 6 | puerto colombia
# City ID: 3671497
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 6 | farafangana
# City ID: 1065158
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 6 | aflu
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 6 | balimo
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 6 | waingapu
# City ID: 1622318
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 6 | talas
# City ID: 299900
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 6 | carora
# City ID: 3646487
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 6 | inza
# City ID: 556283
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 6 | shimoda
# City ID: 1852357
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 6 | georgetown
# City ID: 1735106
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 6 | khatanga
# City ID: 2022572
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 6 | quillota
# City ID: 3874119
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 6 | goderich
# City ID: 5962442
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 6 | walvis bay
# City ID: 3359638
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 6 | vestmannaeyjar
# City ID: 3412093
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 6 | shingu
# City ID: 1847947
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 6 | sikonge
# City ID: 149929
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 6 | ribeira grande
# City ID: 3372707
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 6 | abnub
# City ID: 362973
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 6 | salalah
# City ID: 286621
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 6 | hailar
# City ID: 2037078
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 6 | burkhala
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 6 | shahrud
# City ID: 135423
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 6 | axim
# City ID: 2303611
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 6 | poum
# City ID: 2138555
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 6 | tacuati
# City ID: 3436880
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 6 | phangnga
# City ID: 1151464
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 6 | manzil tamim
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 6 | kondinskoye
# City ID: 1502697
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 6 | crab hill
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 6 | college
# City ID: 5859699
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 6 | mackay
# City ID: 2159220
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 6 | bourail
# City ID: 2141714
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 34 of Set 6 | tambacounda
# City ID: 2244991
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 35 of Set 6 | asyut
# City ID: 359783
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 36 of Set 6 | norrtalje
# City ID: 2688250
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 37 of Set 6 | bhadrachalam
# City ID: 1276328
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 38 of Set 6 | mogadishu
# City ID: 53654
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 39 of Set 6 | mumford
# City ID: 2297810
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 40 of Set 6 | baykit
# City ID: 1510689
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 41 of Set 6 | beringovskiy
# City ID: 2126710
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 42 of Set 6 | nouadhibou
# City ID: 2377457
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 43 of Set 6 | jacareacanga
# City ID: 3397763
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 44 of Set 6 | cidreira
# City ID: 3466165
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 45 of Set 6 | moron
# City ID: 3430545
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 46 of Set 6 | phalaborwa
# City ID: 965528
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 47 of Set 6 | beloha
# City ID: 1067565
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 48 of Set 6 | mrirt
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 49 of Set 6 | carnarvon
# City ID: 2074865
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 50 of Set 6 | samusu
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 0 of Set 7 | casa grande
# City ID: 5288636
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 7 | tasiilaq
# City ID: 3424607
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 7 | qui nhon
# City ID: 1568574
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 7 | osakarovka
# City ID: 1520327
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 7 | humaita
# City ID: 3664078
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 7 | haltern
# City ID: 2911395
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 7 | moose factory
# City ID: 6078372
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 7 | calabozo
# City ID: 3647444
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 7 | kargopol
# City ID: 552465
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 7 | timra
# City ID: 2669047
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 7 | iqaluit
# City ID: 5983720
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 7 | alice springs
# City ID: 2077895
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 7 | belushya guba
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 7 | cotonou
# City ID: 2394819
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 7 | jardim
# City ID: 3460087
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 7 | port hardy
# City ID: 6111862
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 7 | san patricio
# City ID: 3985168
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 7 | vostok
# City ID: 2013279
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 7 | elizabeth city
# City ID: 4465088
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 7 | cayenne
# City ID: 3382160
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 7 | teguldet
# City ID: 1489822
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 7 | rio gallegos
# City ID: 3838859
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 7 | vuktyl
# City ID: 470905
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 7 | port lincoln
# City ID: 2063036
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 7 | corning
# City ID: 5113760
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 7 | saint-joseph
# City ID: 6690296
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 7 | nguiu
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 7 | bengkulu
# City ID: 1649150
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 7 | tessalit
# City ID: 2449893
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 7 | san carlos de bariloche
# City ID: 7647007
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 7 | arman
# City ID: 2127060
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 7 | keetmanshoop
# City ID: 3356264
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 7 | birjand
# City ID: 140463
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 7 | antalaha
# City ID: 1071296
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 34 of Set 7 | wajir
# City ID: 178443
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 35 of Set 7 | blythe
# City ID: 5329649
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 36 of Set 7 | yenagoa
# City ID: 2318123
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 37 of Set 7 | sawtell
# City ID: 2150163
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 38 of Set 7 | bertoua
# City ID: 2234359
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 39 of Set 7 | old road
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 40 of Set 7 | goma
# City ID: 216281
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 41 of Set 7 | westport
# City ID: 4845585
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 42 of Set 7 | bondoukou
# City ID: 2291136
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 43 of Set 7 | cavallino
# City ID: 3179323
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 44 of Set 7 | katrineholm
# City ID: 2701223
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 45 of Set 7 | dhidhdhoo
# City ID: 1337612
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 46 of Set 7 | sur
# City ID: 286245
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 47 of Set 7 | la paz
# City ID: 3911925
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 48 of Set 7 | dongsheng
# City ID: 1812256
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 49 of Set 7 | wanaka
# City ID: 2184707
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 50 of Set 7 | pinheiro machado
# City ID: 3453741
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 0 of Set 8 | loa janan
# City ID: 1637510
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 8 | chicama
# City ID: 3698359
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 8 | inuvik
# City ID: 5983607
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 8 | puerto ayacucho
# City ID: 3629710
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 8 | bayir
# City ID: 304183
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 8 | ucluelet
# City ID: 6171633
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 8 | khed brahma
# City ID: 1266806
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 8 | warsaw
# City ID: 756135
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 8 | ayia galini
# City ID: 264260
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 8 | ancud
# City ID: 3899695
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 8 | koson
# City ID: 1217007
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 8 | bonnyville
# City ID: 5905616
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 8 | marrakesh
# City ID: 2542997
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 8 | miri
# City ID: 1738050
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 8 | nandura
# City ID: 1261932
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 8 | urumqi
# City ID: 1529102
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 8 | port augusta
# City ID: 2063056
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 8 | meadow lake
# City ID: 5478673
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 8 | rurrenabaque
# City ID: 3906209
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 8 | cooma
# City ID: 2170577
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 8 | lakes entrance
# City ID: 2160735
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 8 | henties bay
# City ID: 3356832
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 8 | half moon bay
# City ID: 5354943
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 8 | phibun mangsahan
# City ID: 1607730
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 8 | champerico
# City ID: 3598787
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 8 | ayan
# City ID: 2027316
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 8 | batagay-alyta
# City ID: 2027042
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 8 | aksu
# City ID: 1529660
# ...
# City ID: 4513583
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 10 | lompoc
# City ID: 5367788
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 10 | muzquiz
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 10 | klaksvik
# City ID: 2618795
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 10 | praia da vitoria
# City ID: 3372760
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 10 | san rafael
# City ID: 3836669
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 10 | zuwarah
# City ID: 2208425
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 10 | ashqelon
# City ID: 295620
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 10 | lorengau
# City ID: 2092164
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 10 | sao raimundo das mangabeiras
# City ID: 3388147
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 10 | waipawa
# City ID: 2206874
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 10 | kincardine
# City ID: 2645525
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 10 | turukhansk
# City ID: 1488903
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 10 | sao felix do xingu
# City ID: 3388847
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 10 | yefira
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 10 | comodoro rivadavia
# City ID: 3860443
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 10 | rabo de peixe
# City ID: 3372745
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 10 | mineiros
# City ID: 3457147
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 10 | gualaquiza
# City ID: 3657661
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 10 | pitsunda
# City ID: 615460
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 10 | caravelas
# City ID: 3466980
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 10 | coulommiers
# City ID: 3023240
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 10 | wanderlandia
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 10 | greeley
# City ID: 5577592
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 34 of Set 10 | quisqueya
# City ID: 3494121
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 35 of Set 10 | neiafu
# City ID: 4032420
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 36 of Set 10 | aranda de duero
# City ID: 3129877
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 37 of Set 10 | canutama
# City ID: 3664716
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 38 of Set 10 | malatya
# City ID: 304919
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 39 of Set 10 | pemangkat
# City ID: 1631637
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 40 of Set 10 | alofi
# City ID: 4036284
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 41 of Set 10 | hasaki
# City ID: 2112802
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 42 of Set 10 | namatanai
# City ID: 2090021
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 43 of Set 10 | charlestown
# City ID: 2171766
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 44 of Set 10 | ilinsko-podomskoye
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 45 of Set 10 | ambilobe
# City ID: 1082243
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 46 of Set 10 | chimbote
# City ID: 3698304
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 47 of Set 10 | koslan
# City ID: 544084
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 48 of Set 10 | izhmorskiy
# City ID: 1505228
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 49 of Set 10 | tabas
# City ID: 113659
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 50 of Set 10 | tungkang
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 0 of Set 11 | verkhoyansk
# City ID: 2013465
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 11 | owerri
# City ID: 2325330
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 11 | chivay
# City ID: 3943626
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 11 | quatre cocos
# City ID: 1106643
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 11 | petropavlovka
# City ID: 2017979
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 11 | kitob
# City ID: 1216787
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 11 | santo estevao
# City ID: 3449467
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 11 | kutum
# City ID: 371745
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 11 | codrington
# City ID: 2171099
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 11 | luanda
# City ID: 2240449
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 11 | knyaze-volkonskoye
# City ID: 2021954
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 11 | saint-louis
# City ID: 2246451
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 11 | amga
# City ID: 2027786
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 11 | suntar
# City ID: 2015913
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 11 | fatehabad
# City ID: 1271934
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 11 | salinopolis
# City ID: 3389822
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 11 | vila velha
# City ID: 3445026
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 11 | vendas novas
# City ID: 2261740
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 11 | jacqueville
# City ID: 2287778
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 11 | kahului
# City ID: 5847411
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 11 | mount gambier
# City ID: 2156643
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 11 | manado
# City ID: 1636544
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 11 | chokwe
# City ID: 1048364
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 11 | airai
# City ID: 1651810
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 11 | saint-augustin
# City ID: 6137462
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 11 | bosaso
# City ID: 64013
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 11 | naze
# City ID: 1855540
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 11 | chumikan
# City ID: 2025256
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 11 | hofn
# City ID: 2630299
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 11 | griffith
# City ID: 4920986
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 11 | itoman
# City ID: 1861280
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 11 | iralaya
# City ID: 3608828
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 11 | santa cruz
# City ID: 3904906
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 11 | longlac
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 34 of Set 11 | ourossogui
# City ID: 2246922
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 35 of Set 11 | lewisporte
# City ID: 6053446
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 36 of Set 11 | mandalgovi
# City ID: 2030065
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 37 of Set 11 | mizdah
# City ID: 2214827
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 38 of Set 11 | maiduguri
# City ID: 2331447
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 39 of Set 11 | eyl
# City ID: 60019
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 40 of Set 11 | roma
# City ID: 5134295
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 41 of Set 11 | nelson bay
# City ID: 2155562
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 42 of Set 11 | duluth
# City ID: 5024719
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 43 of Set 11 | libertador general san martin
# City ID: 3846915
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 44 of Set 11 | aykhal
# City ID: 2027296
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 45 of Set 11 | brokopondo
# City ID: 3384481
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 46 of Set 11 | tumannyy
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 47 of Set 11 | marshfield
# City ID: 5261969
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 48 of Set 11 | roches noires
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 49 of Set 11 | rantauprapat
# City ID: 1214073
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 50 of Set 11 | isiro
# City ID: 215771
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 0 of Set 12 | porgera
# City ID: 2088143
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 1 of Set 12 | bandipur
# City ID: 1283680
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 2 of Set 12 | guane
# City ID: 3557758
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 3 of Set 12 | orel-izumrud
# City ID: 803494
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 4 of Set 12 | susangerd
# City ID: 137268
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 5 of Set 12 | nizhniy tsasuchey
# City ID: 2019118
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 6 of Set 12 | wembley
# City ID: 2058682
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 7 of Set 12 | wad rawah
# City ID: 364071
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 8 of Set 12 | jose de freitas
# City ID: 3397230
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 9 of Set 12 | eureka
# City ID: 5563397
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 10 of Set 12 | akdepe
# City ID: 601551
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 11 of Set 12 | la ronge
# City ID: 6050066
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 12 of Set 12 | aitape
# City ID: 2101169
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 13 of Set 12 | khash
# City ID: 1160571
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 14 of Set 12 | tabiauea
# City not found. Skipping...
# 'name'
# +++++++++++++++++++++++++++++++++
# Processing Record 15 of Set 12 | maniitsoq
# City ID: 3421982
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 16 of Set 12 | luganville
# City ID: 2136150
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 17 of Set 12 | gerash
# City ID: 133595
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 18 of Set 12 | lynchburg
# City ID: 4771075
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 19 of Set 12 | vernon
# City ID: 6173864
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 20 of Set 12 | poltavka
# City ID: 1494500
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 21 of Set 12 | ulaanbaatar
# City ID: 2028462
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 22 of Set 12 | faya
# City ID: 110690
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 23 of Set 12 | tuensang
# City ID: 1254133
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 24 of Set 12 | samaniego
# City ID: 3670293
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 25 of Set 12 | tartasesti
# City ID: 665479
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 26 of Set 12 | outjo
# City ID: 3353715
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 27 of Set 12 | paamiut
# City ID: 3421193
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 28 of Set 12 | maumere
# City ID: 1635815
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 29 of Set 12 | guilin
# City ID: 1809498
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 30 of Set 12 | dungarvan
# City ID: 2964528
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 31 of Set 12 | taoudenni
# City ID: 2450173
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 32 of Set 12 | san jose de guanipa
# City ID: 3628142
# +++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++
# Processing Record 33 of Set 12 | belmonte
# City ID: 3470137
# +++++++++++++++++++++++++++++++++
# ###################################
# Completed!!!!!
# ###################################

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create the data Frame
Weather_Data_DF = pd.DataFrame({"City" : Selected_City,
                                "City_ID" : City_ID,
                                "Country" : Country,
                                "Latitude" : Latitude,
                                "Longitude" : Longitude,
                                "Temperature" : Temperature,
                                "Humidity" : Humidity,
                                "Max Temp" : Max_Temp,
                                "Wind Speed" : Wind_Speed,
                                "Cloudiness" : Cloudiness
})      
Weather_Data_DF.head()
# Out:
#            City  City_ID Country  Latitude  Longitude  Temperature  Humidity  \
# 0       Methóni   257122      GR     36.82      21.70       282.58        93
# 1  Puerto Ayora  3652764      EC     -0.74     -90.35       299.58        78
# 2         Vaini  4032243      TO    -21.20    -175.20       302.15        66
# 3  Ponta do Sol  2264557      PT     32.67     -17.10       285.70        71
# 4       Ushuaia  3833367      AR    -54.80     -68.30       280.15        65
#
#    Max Temp  Wind Speed  Cloudiness
# 0    284.82         1.0          43
# 1    300.15         3.6          20
# 2    302.15         4.6          75
# 3    287.15         2.1          20
# 4    280.15         6.2          40

# %%
# Export to CSV
Weather_Data_DF.to_csv("002-Output/Weather_Data_DF.csv",
                   index=False, 
                   header=True
                  )

# %%
Weather_Data_DF.columns
# Out:
# Index(['City', 'City_ID', 'Country', 'Latitude', 'Longitude', 'Temperature',
#        'Humidity', 'Max Temp', 'Wind Speed', 'Cloudiness'],
#       dtype='object')

# %%
Weather_Data_DF.dtypes
# Out:
# City            object
# City_ID          int64
# Country         object
# Latitude       float64
# Longitude      float64
# Temperature    float64
# Humidity         int64
# Max Temp       float64
# Wind Speed     float64
# Cloudiness       int64
# dtype: object

# %%
Weather_Data_DF.count()
# Out:
# City           545
# City_ID        545
# Country        545
# Latitude       545
# Longitude      545
# Temperature    545
# Humidity       545
# Max Temp       545
# Wind Speed     545
# Cloudiness     545
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(Weather_Data_DF["Latitude"],
            Weather_Data_DF["Temperature"],
            marker = "o"
           )
plt.plot()
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Latitude vs. Temperature Plot (F)')
plt.savefig('002-Output/Latitude_vs_Temperature_Plot (F).png')


print("""This code analyses if there is a relationship between the latitude and the temperature, using a scatter plot. 
The plot shows that the temperature decreases the more you go away from the Equator (Latitude).
""")
# Out:
# This code analyses if there is a relationship between the latitude and the temperature, using a scatter plot.
# The plot shows that the temperature decreases the more you go away from the Equator (Latitude).

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(Weather_Data_DF["Latitude"],
            Weather_Data_DF["Humidity"],
            marker = "o"
           )
plt.xlabel('Latitude')
plt.ylabel('Humidity Plot')
plt.title('Latitude vs. Humidity Plot')
plt.savefig('002-Output/Latitude vs Humidity Plot.png')

print("""This code analyses if there is a relationship between the latitude and the humidity, using a scatter plot.
Based on the chart, there is no relation.""")
# Out:
# This code analyses if there is a relationship between the latitude and the humidity, using a scatter plot.
# Based on the chart, there is no relation.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(Weather_Data_DF["Latitude"],
            Weather_Data_DF["Cloudiness"],
            marker = "o"
           )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness Plot')
plt.title('Latitude vs. Cloudiness Plot')
plt.savefig('002-Output/Latitude vs Cloudiness Plot.png')

print("""This code analyses if there is a relationship between the latitude and the cloudiness, using a scatter plot.
Based on the chart, there is no relation.""")
# Out:
# This code analyses if there is a relationship between the latitude and the cloudiness, using a scatter plot.
# Based on the chart, there is no relation.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(Weather_Data_DF["Latitude"],
            Weather_Data_DF["Wind Speed"],
            marker = "o"
           )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed Plot (mph)')
plt.title('Latitude vs. Wind Speed Plot (mph)')
plt.savefig('002-Output/Latitude vs Wind Speed Plot (mph).png')

print("""This code analyses if there is a relationship between the latitude and the wind speed, using a scatter plot.
Based on the chart, there is no relation.""")
# Out:
# This code analyses if there is a relationship between the latitude and the wind speed, using a scatter plot.
# Based on the chart, there is no relation.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %%
# NorthernHemisphere DataFrames
Northern_DF = Weather_Data_DF.loc[Weather_Data_DF["Latitude"] >= 0, :]
Northern_DF.head()
# Out:
#             City  City_ID Country  Latitude  Longitude  Temperature  Humidity  \
# 0        Methóni   257122      GR     36.82      21.70       282.58        93
# 3   Ponta do Sol  2264557      PT     32.67     -17.10       285.70        71
# 6    San Quintín  3984997      MX     30.48    -115.95       288.27        56
# 9        Mattawa  5802636      US     46.74    -119.90       286.30        44
# 10        Albany  5106841      US     42.60     -73.97       280.38        68
#
#     Max Temp  Wind Speed  Cloudiness
# 0     284.82         1.0          43
# 3     287.15         2.1          20
# 6     288.27         9.8           0
# 9     288.15         4.6          90
# 10    283.15         5.1           1

# %%
# Southern Hemisphere DataFrames

# %%
Southern_DF = Weather_Data_DF.loc[Weather_Data_DF["Latitude"] < 0, :]
Southern_DF.head()
# Out:
#            City  City_ID Country  Latitude  Longitude  Temperature  Humidity  \
# 1  Puerto Ayora  3652764      EC     -0.74     -90.35       299.58        78
# 2         Vaini  4032243      TO    -21.20    -175.20       302.15        66
# 4       Ushuaia  3833367      AR    -54.80     -68.30       280.15        65
# 5         Bluff  2206939      NZ    -46.60     168.33       287.04        66
# 7  Punta Arenas  3874787      CL    -53.15     -70.92       278.92        70
#
#    Max Temp  Wind Speed  Cloudiness
# 1    300.15        3.60          20
# 2    302.15        4.60          75
# 4    280.15        6.20          40
# 5    287.04        0.45          72
# 7    279.15        1.15          91

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Northern_DF['Max Temp']
y_values = Northern_DF['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(240,20),fontsize=15,color="red")
plt.xlabel('Max Temp (F)')
plt.ylabel('Latitude')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

print(f"The r-squared is: {rvalue}")
print("""This code analyses if there is a relationship between the Max temperature and the Latitude, using a linear regression.
Based on the chart and the r-value, there is strong negative correlation.""")

plt.show()
plt.savefig('002-Output/Northern Hemisphere - Max Temp  vs Latitude Linear Regression.png')
# Out:
# The r-squared is: -0.9109260398890167
# This code analyses if there is a relationship between the Max temperature and the Latitude, using a linear regression.
# Based on the chart and the r-value, there is strong negative correlation.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern_DF['Max Temp']
y_values = Southern_DF['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(287,-50),fontsize=15,color="red")
plt.xlabel('Max Temp(F)')
plt.ylabel('Latitude')
plt.title('Southern Hemisphere - Max Temp (F) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("""This code analyses if there is a relationship between the Max temperature and the Latitude, using a linear regression.
Based on the chart and the r-value, there is moderate positive correlation.""")
plt.show()
plt.savefig('002-Output/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png')
# Out:
# The r-squared is: 0.5906393998526809
# This code analyses if there is a relationship between the Max temperature and the Latitude, using a linear regression.
# Based on the chart and the r-value, there is moderate positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern_DF['Humidity']
y_values = Northern_DF['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,75),fontsize=15,color="red")
plt.xlabel('Humidity (%)')
plt.ylabel('Latitude')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("""This code analyses if there is a relationship between the Humidity % and the Latitude, using a linear regression.
Based on the chart and the r-value, there is weak positive correlation.""")
plt.show()
plt.savefig('002-Output/Northern Hemisphere - Humidity (%) vs Latitude Linear Regression.png')
# Out:
# The r-squared is: 0.27638396425609285
# This code analyses if there is a relationship between the Humidity % and the Latitude, using a linear regression.
# Based on the chart and the r-value, there is weak positive correlation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern_DF['Humidity']
y_values = Southern_DF['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,-50),fontsize=15,color="red")
plt.xlabel('Humidity (%)')
plt.ylabel('Latitude')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("""This code analyses if there is a relationship between the Humidity % and the Latitude, using a linear regression.
Based on the chart and the r-value, there is weak positive correlation.""")
plt.show()
plt.savefig('002-Output/Southern Hemisphere - Humidity (%) vs Latitude Linear Regression.png')
# Out:
# The r-squared is: 0.3128028401265279
# This code analyses if there is a relationship between the Humidity % and the Latitude, using a linear regression.
# Based on the chart and the r-value, there is weak positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern_DF['Cloudiness']
y_values = Northern_DF['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,75),fontsize=15,color="red")
plt.xlabel('Cloudiness (%)')
plt.ylabel('Latitude')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("""This code analyses if there is a relationship between the Cloudiness % and the Latitude, using a linear regression.
Based on the chart and the r-value, there is weak positive correlation.""")
plt.show()
plt.savefig('002-Output/Northern Hemisphere - Cloudiness (%) vs Latitude Linear Regression.png')
# Out:
# The r-squared is: 0.18414462160181705
# This code analyses if there is a relationship between the Cloudiness % and the Latitude, using a linear regression.
# Based on the chart and the r-value, there is weak positive correlation.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern_DF['Cloudiness']
y_values = Southern_DF['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,-50),fontsize=15,color="red")
plt.xlabel('Cloudiness (%)')
plt.ylabel('Latitude')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("""This code analyses if there is a relationship between the Cloudiness % and the Latitude, using a linear regression.
Based on the chart and the r-value, there is a weak positive correlation.""")
plt.show()
plt.savefig('002-Output/Southern Hemisphere - Cloudiness (%) vs Latitude Linear Regression.png')
# Out:
# The r-squared is: 0.21283745379747457
# This code analyses if there is a relationship between the Cloudiness % and the Latitude, using a linear regression.
# Based on the chart and the r-value, there is a weak positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern_DF['Wind Speed']
y_values = Northern_DF['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,4),fontsize=15,color="red")
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("""This code analyses if there is a relationship between the Wind Speed (mph) % and the Latitude, using a linear regression.
Based on the chart and the r-value, there is a weak positive correlation.""")
plt.show()
plt.savefig('002-Output/Northern Hemisphere - Wind Speed (mph) vs Latitude Linear Regression.png')
# Out:
# The r-squared is: 0.18450691689750182
# This code analyses if there is a relationship between the Wind Speed (mph) % and the Latitude, using a linear regression.
# Based on the chart and the r-value, there is a weak positive correlation.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern_DF['Wind Speed']
y_values = Southern_DF['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,-55),fontsize=15,color="red")
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("""This code analyses if there is a relationship between the Wind Speed % and the Latitude, using a linear regression.
Based on the chart and the r-value, there is weak negative correlation.""")
plt.show()
plt.savefig('002-Output/Southern Hemisphere - Wind Speed (mph) vs Latitude Linear Regression.png')
# Out:
# The r-squared is: -0.24498480975451176
# This code analyses if there is a relationship between the Wind Speed % and the Latitude, using a linear regression.
# Based on the chart and the r-value, there is weak negative correlation.
